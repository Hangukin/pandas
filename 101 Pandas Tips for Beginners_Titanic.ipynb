# %%
pwd
# Out:
# 'C:\\Users\\korean\\practice'

# %% [raw]
# https://www.kaggle.com/joshuajhchoi/101-pandas-tips-for-beginners-titanic-en-kr
#
# 이 것은 Kaggle Titanic Challenge를 처음 하시는데 Pandas에 대해서 잘 모르는 분들을 위한 쉬운 판다스 가이드북입니다.

# %% [raw]
# Part 1 - Exploring Data
# Part 2 - Indexing
# Part 3 - Sorting
# Part 4 - Creating
# part 5 - Extracting
# part 6 - Grouping
# Part 7 - Appending/Inserting
# Part 8 - Replacing
# Part 9 - Others

# %% [markdown]
# # Part 1 - Exploring Data

# %%
# No. 1 - To read a CSV and turn them into a dataframe.

# %%
import numpy as np
import pandas as pd

# 시각화 관련 라이브러리
# %matplotlib inline                
# 쥬피터 노트북 라인에 바로 그래프 그릴 수 있게
import matplotlib.pyplot as plt    # 시각화
plt.style.use('seaborn-whitegrid')   # 스타일 적용
import seaborn as sns     # 시각화

# %%
test = pd.read_csv('data_titanic/test.csv')
train = pd.read_csv('data_titanic/train.csv')

# %%
print(train.shape)
train.head(3)
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
print(test.shape)
test.head(3)
# Out:
# (418, 11)
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
# No. 2 - To read the first 5 lines of train

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# No. 3 _ To read the first 10 lines of train

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# No. 4 - To read all of train

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# No. 5 - To read bottom 5 lines

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# No. 6 - To read bottom 10 lines

# %%
train.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
# No. 7 - To read lines from 101 to 110

# %%
train[101:111]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
# 107          108         1       3            Moss, Mr. Albert Johan    male
# 108          109         0       3                   Rekic, Mr. Tido    male
# 109          110         1       3               Moran, Miss. Bertha  female
# 110          111         0       1    Porter, Mr. Walter Chamberlain    male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 101   NaN      0      0   349215   7.8958   NaN        S
# 102  21.0      0      1    35281  77.2875   D26        S
# 103  33.0      0      0     7540   8.6542   NaN        S
# 104  37.0      2      0  3101276   7.9250   NaN        S
# 105  28.0      0      0   349207   7.8958   NaN        S
# 106  21.0      0      0   343120   7.6500   NaN        S
# 107   NaN      0      0   312991   7.7750   NaN        S
# 108  38.0      0      0   349249   7.8958   NaN        S
# 109   NaN      1      0   371110  24.1500   NaN        Q
# 110  47.0      0      0   110465  52.0000  C110        S

# %%
# No. 8 describe() - to see the data details such as , counts, means and so on.

# %%
train.describe() # 통계값
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# No. 9 info() - to see the types of data for each column

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# No. 10 - shape to check the shape of the data

# %%
train.shape
# Out:
# (891, 12)

# %%
# No. 11 - dtypes to check the types of data

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# No. 12 - len to check the length of the dataframe

# %%
len(train)  #행 ( row )수 , 샘플 수
# Out:
# 891

# %%
# No. 13 - To check the column heads

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Part 2 - Indexing

# %%
# No. 14 - To see a certain column head

# %%
train.columns[3]
# Out:
# 'Name'

# %%
# No. 15 - To see multiple column heads

# %%
train.columns[3:5]
# Out:
# Index(['Name', 'Sex'], dtype='object')

# %%
# No. 16 - To see the values of a certain column

# %%
train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# No. 17 isnull().any()/ isna().any() 
# - To check if there are any null values (empty or NaN (Not a Number))

# %%
train.isnull().sum() # NULL값 갯수
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# No. 18 - isnull().sum()/isna().sum() To check the sum counts of null values

# %%
train.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# No. 19 - Locating - loc - To read a certain row

# %%
print(train.loc[3]) # 3번째 행 값들 출력
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
train.loc[train['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 11       0    113783  26.5500         C103        S
# 23       0    113788  35.5000           A6        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [216 rows x 12 columns]

# %%
train.loc[train['Pclass']==1].reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             12         1       1
# 4             24         1       1
# ..           ...       ...     ...
# 211          872         1       1
# 212          873         0       1
# 213          880         1       1
# 214          888         1       1
# 215          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                             Bonnell, Miss. Elizabeth  female  58.0      0
# 4                         Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 211   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 212                           Carlsson, Mr. Frans Olof    male  33.0      0
# 213      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 214                       Graham, Miss. Margaret Edith  female  19.0      0
# 215                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 0        0  PC 17599  71.2833          C85        C
# 1        0    113803  53.1000         C123        S
# 2        0     17463  51.8625          E46        S
# 3        0    113783  26.5500         C103        S
# 4        0    113788  35.5000           A6        S
# ..     ...       ...      ...          ...      ...
# 211      1     11751  52.5542          D35        S
# 212      0       695   5.0000  B51 B53 B55        S
# 213      1     11767  83.1583          C50        C
# 214      0    112053  30.0000          B42        S
# 215      0    111369  30.0000         C148        C
#
# [216 rows x 12 columns]

# %%
# No 20. - To read a cerain column

# %%
train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# No. 21 - Locating - loc - To read items with a certain condition

# %%
print('처음',train.loc[train.Age.values < 1])
# Out:
# 처음      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# 755  0.67      1      1  250649   14.5000      NaN        S
# 803  0.42      0      1    2625    8.5167      NaN        C
# 831  0.83      1      1   29106   18.7500      NaN        S

# %%
# No. 22 - Locating - loc - To read the item in a certain row and certain column

# %%
train.loc[9, 'Name']
# Out:
# 'Nasser, Mrs. Nicholas (Adele Achem)'

# %%
train.loc[9, ['Name', 'Age']]
# Out:
# Name    Nasser, Mrs. Nicholas (Adele Achem)
# Age                                    14.0
# Name: 9, dtype: object

# %%
# No. 23 - iloc - To read certain rows

# %%
train.iloc[11:21]
# Out:
#     PassengerId  Survived  Pclass  \
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 11      0     113783  26.5500  C103        S
# 12      0  A/5. 2151   8.0500   NaN        S
# 13      5     347082  31.2750   NaN        S
# 14      0     350406   7.8542   NaN        S
# 15      0     248706  16.0000   NaN        S
# 16      1     382652  29.1250   NaN        Q
# 17      0     244373  13.0000   NaN        S
# 18      0     345763  18.0000   NaN        S
# 19      0       2649   7.2250   NaN        C
# 20      0     239865  26.0000   NaN        S

# %%
train.loc[11:21]
# Out:
#     PassengerId  Survived  Pclass  \
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 11      0     113783  26.5500  C103        S
# 12      0  A/5. 2151   8.0500   NaN        S
# 13      5     347082  31.2750   NaN        S
# 14      0     350406   7.8542   NaN        S
# 15      0     248706  16.0000   NaN        S
# 16      1     382652  29.1250   NaN        Q
# 17      0     244373  13.0000   NaN        S
# 18      0     345763  18.0000   NaN        S
# 19      0       2649   7.2250   NaN        C
# 20      0     239865  26.0000   NaN        S
# 21      0     248698  13.0000   D56        S

# %%
# No. 24 - iloc - To read a single row

# %%
train.iloc[21]
# Out:
# PassengerId                       22
# Survived                           1
# Pclass                             2
# Name           Beesley, Mr. Lawrence
# Sex                             male
# Age                             34.0
# SibSp                              0
# Parch                              0
# Ticket                        248698
# Fare                            13.0
# Cabin                            D56
# Embarked                           S
# Name: 21, dtype: object

# %%
# No. 25 - If there are too many columns, you can reduce the number of columns it displays

# %%
#판다스 컬럼 제한 해제
pd.set_option("display.max_columns", 12)  #컬럼 숫자 만큼 다 보여줌 
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Part 3 - Sorting

# %%
# No. 26 - Sorting columns with descending order

# %%
train.sort_values('Fare', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 633    male   NaN      0      0    112052    0.0000          NaN        S
# 413    male   NaN      0      0    239853    0.0000          NaN        S
# 822    male  38.0      0      0     19972    0.0000          NaN        S
# 732    male   NaN      0      0    239855    0.0000          NaN        S
# 674    male   NaN      0      0    239856    0.0000          NaN        S
#
# [891 rows x 12 columns]

# %%
# No. 27- Sorting columns with ascending order

# %%
train.sort_values('Fare', ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 271    male  25.0      0      0      LINE    0.0000          NaN        S
# 597    male  49.0      0      0      LINE    0.0000          NaN        S
# 302    male  19.0      0      0      LINE    0.0000          NaN        S
# 633    male   NaN      0      0    112052    0.0000          NaN        S
# 277    male   NaN      0      0    239853    0.0000          NaN        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# 341  female  24.0      3      2     19950  263.0000  C23 C25 C27        S
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
#
# [891 rows x 12 columns]

# %%
# No. 28 - Sorting columns - looking at certain rows

# %%
train.sort_values('Fare', ascending=True)[101:105]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 421          422         0       3               Charters, Mr. David    male
# 156          157         1       3  Gilnagh, Miss. Katherine "Katie"  female
# 778          779         0       3           Kilgannon, Mr. Thomas J    male
# 727          728         1       3          Mannion, Miss. Margareth  female
#
#       Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 421  21.0      0      0  A/5. 13032  7.7333   NaN        Q
# 156  16.0      0      0       35851  7.7333   NaN        Q
# 778   NaN      0      0       36865  7.7375   NaN        Q
# 727   NaN      0      0       36866  7.7375   NaN        Q

# %%
# No. 29 - Sorting columns - multi columns in ascending order

# %%
train.sort_values(['Fare', 'Survived', 'Pclass'], ascending=[True, False, False])
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 179          180         0       3                 Leonard, Mr. Lionel
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 597          598         0       3                 Johnson, Mr. Alfred
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 438          439         0       1                   Fortune, Mr. Mark
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 271    male  25.0      0      0      LINE    0.0000          NaN        S
# 179    male  36.0      0      0      LINE    0.0000          NaN        S
# 302    male  19.0      0      0      LINE    0.0000          NaN        S
# 597    male  49.0      0      0      LINE    0.0000          NaN        S
# 277    male   NaN      0      0    239853    0.0000          NaN        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
# [891 rows x 12 columns]

# %%
# No. 30 - Sorting a certain column with a certain condition

# %%
train[train['Fare'] > 80]
pd.set_option("display.max_rows", 3)
print(train.head(5))
pd.reset_option('display.max_rows')
print(train.head(5))
# Out:
#     PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 0             1         0       3   Braund, Mr. Owen Harris  male  22.0
# ..          ...       ...     ...                       ...   ...   ...
# 4             5         0       3  Allen, Mr. William Henry  male  35.0
#
#     SibSp  Parch     Ticket  Fare Cabin Embarked
# 0       1      0  A/5 21171  7.25   NaN        S
# ..    ...    ...        ...   ...   ...      ...
# 4       0      0     373450  8.05   NaN        S
#
# [5 rows x 12 columns]
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# No. 31 - Sort by a certain column's order(Ascending)

# %%
train.sort_values(by=['Pclass'])
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
# ..           ...       ...     ...
# 379          380         0       3
# 381          382         1       3
# 382          383         0       3
# 371          372         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
# ..                                                 ...     ...   ...    ...
# 379                        Gustafsson, Mr. Karl Gideon    male  19.0      0
# 381                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 382                                 Tikkanen, Mr. Juho    male  32.0      0
# 371                          Wiklund, Mr. Jakob Alfred    male  18.0      1
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch             Ticket      Fare Cabin Embarked
# 445      2              33638   81.8583   A34        S
# 310      0              11767   83.1583   C54        C
# 309      0           PC 17485   56.9292   E36        C
# 307      0           PC 17758  108.9000   C65        C
# 306      0              17421  110.8833   NaN        C
# ..     ...                ...       ...   ...      ...
# 379      0             347069    7.7750   NaN        S
# 381      2               2653   15.7417   NaN        C
# 382      0  STON/O 2. 3101293    7.9250   NaN        S
# 371      0            3101267    6.4958   NaN        S
# 890      0             370376    7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# No. 32 - Sort Columns by alphabetical order

# %%
train.reindex(sorted(train.columns), axis=1) # 컬럼 기준 재정렬 로우는 axis = 0
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# 886                              Montvila, Rev. Juozas      0          887
# 887                       Graham, Miss. Margaret Edith      0          888
# 888           Johnston, Miss. Catherine Helen "Carrie"      2          889
# 889                              Behr, Mr. Karl Howell      0          890
# 890                                Dooley, Mr. Patrick      0          891
#
#      Pclass     Sex  SibSp  Survived            Ticket
# 0         3    male      1         0         A/5 21171
# 1         1  female      1         1          PC 17599
# 2         3  female      0         1  STON/O2. 3101282
# 3         1  female      1         1            113803
# 4         3    male      0         0            373450
# ..      ...     ...    ...       ...               ...
# 886       2    male      0         0            211536
# 887       1  female      0         1            112053
# 888       3  female      1         0        W./C. 6607
# 889       1    male      0         1            111369
# 890       3    male      0         0            370376
#
# [891 rows x 12 columns]

# %%
train.sort_index(axis=1)
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# 886                              Montvila, Rev. Juozas      0          887
# 887                       Graham, Miss. Margaret Edith      0          888
# 888           Johnston, Miss. Catherine Helen "Carrie"      2          889
# 889                              Behr, Mr. Karl Howell      0          890
# 890                                Dooley, Mr. Patrick      0          891
#
#      Pclass     Sex  SibSp  Survived            Ticket
# 0         3    male      1         0         A/5 21171
# 1         1  female      1         1          PC 17599
# 2         3  female      0         1  STON/O2. 3101282
# 3         1  female      1         1            113803
# 4         3    male      0         0            373450
# ..      ...     ...    ...       ...               ...
# 886       2    male      0         0            211536
# 887       1  female      0         1            112053
# 888       3  female      1         0        W./C. 6607
# 889       1    male      0         1            111369
# 890       3    male      0         0            370376
#
# [891 rows x 12 columns]

# %%
# No. 33 - Multi Column filtering

# %%
train[(train.Age >= 30) & (train.Sex == 'female')].reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2             12         1       1
# 3             16         1       2
# 4             19         0       3
# ..           ...       ...     ...
# 109          863         1       1
# 110          866         1       2
# 111          872         1       1
# 112          880         1       1
# 113          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                             Bonnell, Miss. Elizabeth  female  58.0      0
# 3                     Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 4    Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 109  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 110                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 111   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 112      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 113               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 0        0  PC 17599  71.2833   C85        C
# 1        0    113803  53.1000  C123        S
# 2        0    113783  26.5500  C103        S
# 3        0    248706  16.0000   NaN        S
# 4        0    345763  18.0000   NaN        S
# ..     ...       ...      ...   ...      ...
# 109      0     17466  25.9292   D17        S
# 110      0    236852  13.0000   NaN        S
# 111      1     11751  52.5542   D35        S
# 112      1     11767  83.1583   C50        C
# 113      5    382652  29.1250   NaN        Q
#
# [114 rows x 12 columns]

# %%
# No. 34 - isin - filtering by conditions

# %%
train[train.Embarked.isin(['C'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch         Ticket     Fare Cabin Embarked
# 1        0       PC 17599  71.2833   C85        C
# 9        0         237736  30.0708   NaN        C
# 19       0           2649   7.2250   NaN        C
# 26       0           2631   7.2250   NaN        C
# 30       0       PC 17601  27.7208   NaN        C
# ..     ...            ...      ...   ...      ...
# 866      0  SC/PARIS 2149  13.8583   NaN        C
# 874      0      P/PP 3381  24.0000   NaN        C
# 875      0           2667   7.2250   NaN        C
# 879      1          11767  83.1583   C50        C
# 889      0         111369  30.0000  C148        C
#
# [168 rows x 12 columns]

# %%
# No. 35 - filtering by multi conditions in a column

# %%
train[train.Cabin.isin(['C50', 'C85'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 879      1     11767  83.1583   C50        C

# %%
# No. 36 - isin - filtering by conditions multi conditions in multi columns

# %%
train[train.Ticket.isin(['113572']) & train.Parch.isin([0])]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# No. 37 - Sorting and Counting sorted values

# %%
len(train[train.Fare == 80.0])
# Out:
# 2

# %%
# No. 38 - Sorting with conditions and counting the sorted values

# %%
len(train[train.Fare > 80.0])
# Out:
# 74

# %%
# No. 39 - Sorting with conditions and if there are any that matches

# %%
(train.Fare > 80.0).any()
# Out:
# True

# %%
# No. 40 - Sorting with conditions and get the percentage

# %%
(train.Fare > 80.0).mean()
# Out:
# 0.08305274971941638

# %% [markdown]
# # Part 4 Creating

# %%
# No. 41 - Making a new empty DataFrame

# %%
sample = pd.DataFrame()

# %%
# No. 42 - Copying and creating a new DataFrame

# %%
temp = train.copy() # 원본데이터 분리, 새롭게 변수 저장 

temp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [raw]
# (참고) 얕은 복사와 깊은 복사(.copy()) : https://mizykk.tistory.com/63

# %%
# No. 43 - Creating a new column

# %%
# 맨 끝에 새로운 컬럼 추가하기
temp['New']  = 0

temp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  ...  \
# 0                            Braund, Mr. Owen Harris    male  22.0  ...
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  ...
# 2                             Heikkinen, Miss. Laina  female  26.0  ...
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  ...
# 4                           Allen, Mr. William Henry    male  35.0  ...
#
#    Parch            Ticket     Fare  Cabin Embarked New
# 0      0         A/5 21171   7.2500    NaN        S   0
# 1      0          PC 17599  71.2833    C85        C   0
# 2      0  STON/O2. 3101282   7.9250    NaN        S   0
# 3      0            113803  53.1000   C123        S   0
# 4      0            373450   8.0500    NaN        S   0
#
# [5 rows x 13 columns]

# %%
# 특정 위치에 새로운 컬럼 추가하기
temp.insert(0, 'New2', 0) #(위치, 컬럼명, 값 )

# %%
temp
# Out:
#      New2  PassengerId  Survived  Pclass  \
# 0       0            1         0       3
# 1       0            2         1       1
# 2       0            3         1       3
# 3       0            4         1       1
# 4       0            5         0       3
# ..    ...          ...       ...     ...
# 886     0          887         0       2
# 887     0          888         1       1
# 888     0          889         0       3
# 889     0          890         1       1
# 890     0          891         0       3
#
#                                                   Name     Sex  ...  Parch  \
# 0                              Braund, Mr. Owen Harris    male  ...      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...      0
# 2                               Heikkinen, Miss. Laina  female  ...      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...      0
# 4                             Allen, Mr. William Henry    male  ...      0
# ..                                                 ...     ...  ...    ...
# 886                              Montvila, Rev. Juozas    male  ...      0
# 887                       Graham, Miss. Margaret Edith  female  ...      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  ...      2
# 889                              Behr, Mr. Karl Howell    male  ...      0
# 890                                Dooley, Mr. Patrick    male  ...      0
#
#                Ticket     Fare Cabin  Embarked New
# 0           A/5 21171   7.2500   NaN         S   0
# 1            PC 17599  71.2833   C85         C   0
# 2    STON/O2. 3101282   7.9250   NaN         S   0
# 3              113803  53.1000  C123         S   0
# 4              373450   8.0500   NaN         S   0
# ..                ...      ...   ...       ...  ..
# 886            211536  13.0000   NaN         S   0
# 887            112053  30.0000   B42         S   0
# 888        W./C. 6607  23.4500   NaN         S   0
# 889            111369  30.0000  C148         C   0
# 890            370376   7.7500   NaN         Q   0
#
# [891 rows x 14 columns]

# %%
# No. 44 - Creating a new column by copying an existing column

# %%
temp['New']  = temp['Age']

temp.head()
# Out:
#    New2  PassengerId  Survived  Pclass  \
# 0     0            1         0       3
# 1     0            2         1       1
# 2     0            3         1       3
# 3     0            4         1       1
# 4     0            5         0       3
#
#                                                 Name     Sex  ...  Parch  \
# 0                            Braund, Mr. Owen Harris    male  ...      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...      0
# 2                             Heikkinen, Miss. Laina  female  ...      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...      0
# 4                           Allen, Mr. William Henry    male  ...      0
#
#              Ticket     Fare Cabin  Embarked   New
# 0         A/5 21171   7.2500   NaN         S  22.0
# 1          PC 17599  71.2833   C85         C  38.0
# 2  STON/O2. 3101282   7.9250   NaN         S  26.0
# 3            113803  53.1000  C123         S  35.0
# 4            373450   8.0500   NaN         S  35.0
#
# [5 rows x 14 columns]

# %%
# No. 45 - Creating a new Dataframe with a certain column

# %%
# 종속 변수, Label , Y값
y_train = train['Survived'] 

y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# No. 46 - Creating a new Dataframe with certain rows

# %%
sample1 = train[0:3] 

sample1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# No. 47 - Creating a new Dataframe with certain columns

# %%
sample2 = train[['Pclass', 'Name', 'Sex']]  # Make sure there are two square brackets 대괄호 두 개 임을 명심하세요.

sample2.head()
# Out:
#    Pclass                                               Name     Sex
# 0       3                            Braund, Mr. Owen Harris    male
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male

# %%
# No. 48 - Creating a new Dataframe with certain columns and certain rows

# %%
sample3 = train[['Pclass', 'Name', 'Sex']] [1:3]

sample3.head()
# Out:
#    Pclass                                               Name     Sex
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female

# %%
# No. 49 - Creating a new Dataframe with exisiting rows that matches a certain condition

# %%
sample4 = train.loc[train.Survived.values == 1]

sample4.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 15           16         1       2
# 17           18         1       2
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 15      0            248706  16.0000   NaN        S
# 17      0            244373  13.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
# No. 50 - Creating a new Dataframe with exisiting rows that matches multiple conditions

# %%
sample5 = train.loc[(train.Survived.values == 1 ) & (train.Pclass.values == 3 ) & (train.Sex.values == 'male' )]

sample5.head()
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 36            37         1       3             Mamee, Mr. Hanna  male   NaN
# 65            66         1       3     Moubarek, Master. Gerios  male   NaN
# 74            75         1       3                Bing, Mr. Lee  male  32.0
# 81            82         1       3  Sheerlinck, Mr. Jan Baptist  male  29.0
# 107          108         1       3       Moss, Mr. Albert Johan  male   NaN
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 36       0      0    2677   7.2292   NaN        C
# 65       1      1    2661  15.2458   NaN        C
# 74       0      0    1601  56.4958   NaN        S
# 81       0      0  345779   9.5000   NaN        S
# 107      0      0  312991   7.7750   NaN        S

# %%
# No. 51 - Concat - Merging and creating a new data frame

# %%
data = pd.concat((train, test), sort=True) # 행기준 위아래 합치기 

print(data.shape)
data.tail()
# Out:
# (1309, 12)
#       Age Cabin Embarked      Fare                          Name  Parch  \
# 413   NaN   NaN        S    8.0500            Spector, Mr. Woolf      0
# 414  39.0  C105        C  108.9000  Oliva y Ocana, Dona. Fermina      0
# 415  38.5   NaN        S    7.2500  Saether, Mr. Simon Sivertsen      0
# 416   NaN   NaN        S    8.0500           Ware, Mr. Frederick      0
# 417   NaN   NaN        C   22.3583      Peter, Master. Michael J      1
#
#      PassengerId  Pclass     Sex  SibSp  Survived              Ticket
# 413         1305       3    male      0       NaN           A.5. 3236
# 414         1306       1  female      0       NaN            PC 17758
# 415         1307       3    male      0       NaN  SOTON/O.Q. 3101262
# 416         1308       3    male      0       NaN              359309
# 417         1309       3    male      1       NaN                2668

# %% [markdown]
# # part 5 Extracting

# %% [raw]
# 정규표현식 나중에 배울 예정

# %% [markdown]
# # Part 6 - Grouping

# %%
# No. 62 - filtering small categories using nlargest()

# %%
print('인덱스값',train.Parch.value_counts())
print('총갯수',train.Parch.value_counts().sum())
# value_counts() Parch 값 갯수
# value_counts.sum() 갯수들의 합
# Out:
# 인덱스값 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
# 총갯수 891

# %%
# 특정 컬럼의 유일값 세고 top 3 뽑기
top3 = train.Parch.value_counts().nlargest(3)
print (top3)
# Out:
# 0    678
# 1    118
# 2     80
# Name: Parch, dtype: int64

# %%
train.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# No. 63 - Narrowing down (filtering small categories using threshold)

# %%
frequencies = data["SibSp"].value_counts(normalize = True) # normalize 분표화 확률로 보임 
frequencies
# Out:
# 0    0.680672
# 1    0.243697
# 2    0.032086
# 4    0.016807
# 3    0.015279
# 8    0.006875
# 5    0.004584
# Name: SibSp, dtype: float64

# %%
# 특정 기준보다 작은 것 찾기
threshold = 0.015 # 기준값
small_categories = frequencies[frequencies < threshold].index
small_categories
# Out:
# Int64Index([8, 5], dtype='int64')

# %%
# 원하는 그룹만 추출하기
a = data.groupby('Pclass').get_group(1) # 1인 P클래스만 뽑아내기
a
# Out:
#       Age Cabin Embarked      Fare  \
# 1    38.0   C85        C   71.2833
# 3    35.0  C123        S   53.1000
# 6    54.0   E46        S   51.8625
# 11   58.0  C103        S   26.5500
# 23   28.0    A6        S   35.5000
# ..    ...   ...      ...       ...
# 403  17.0   NaN        S   47.1000
# 404  43.0   D40        C   27.7208
# 407  50.0   C80        C  211.5000
# 411  37.0   C78        Q   90.0000
# 414  39.0  C105        C  108.9000
#
#                                                   Name  Parch  PassengerId  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 6                              McCarthy, Mr. Timothy J      0            7
# 11                            Bonnell, Miss. Elizabeth      0           12
# 23                        Sloper, Mr. William Thompson      0           24
# ..                                                 ...    ...          ...
# 403                             Carrau, Mr. Jose Pedro      0         1295
# 404                       Frauenthal, Mr. Isaac Gerald      0         1296
# 407                         Widener, Mr. George Dunton      1         1299
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 414                       Oliva y Ocana, Dona. Fermina      0         1306
#
#      Pclass     Sex  SibSp  Survived    Ticket
# 1         1  female      1       1.0  PC 17599
# 3         1  female      1       1.0    113803
# 6         1    male      0       0.0     17463
# 11        1  female      0       1.0    113783
# 23        1    male      0       1.0    113788
# ..      ...     ...    ...       ...       ...
# 403       1    male      0       NaN    113059
# 404       1    male      1       NaN     17765
# 407       1    male      1       NaN    113503
# 411       1  female      1       NaN     19928
# 414       1  female      0       NaN  PC 17758
#
# [323 rows x 12 columns]

# %%
# No. 64 - Groupby - Count

# %% [raw]
# https://rfriend.tistory.com/391

# %%
# count : 그룹 내 non-NA 개수 
train.groupby(['Pclass','Parch'])['Pclass'].count().to_frame()
# Out:
#               Pclass
# Pclass Parch
# 1      0         163
#        1          31
#        2          21
#        4           1
# 2      0         134
#        1          32
#        2          16
#        3           2
# 3      0         381
#        1          55
#        2          43
#        3           3
#        4           3
#        5           5
#        6           1

# %%
# sum : 그룹 내 non-NA 합 
train.groupby(['Pclass','Parch'])['Pclass'].sum()
# Out:
# Pclass  Parch
# 1       0         163
#         1          31
#         2          21
#         4           1
# 2       0         268
#         1          64
#         2          32
#         3           4
# 3       0        1143
#         1         165
#         2         129
#         3           9
#         4           9
#         5          15
#         6           3
# Name: Pclass, dtype: int64

# %%
# No. 65 - Groupby - Mean

# %%
train.groupby(['Pclass','Age'])['Survived'].mean() # 평균값
# Out:
# Pclass  Age
# 1       0.92     1.0
#         2.00     0.0
#         4.00     1.0
#         11.00    1.0
#         14.00    1.0
#                 ...
# 3       61.00    0.0
#         63.00    1.0
#         65.00    0.0
#         70.50    0.0
#         74.00    0.0
# Name: Survived, Length: 182, dtype: float64

# %%
# No. 66 - Groupby - count - cmap

# %%
# 데이터프레임으로 만들기 : to_frame()
train.groupby(['Pclass','Survived'])['Pclass'].count().to_frame()
# Out:
#                  Pclass
# Pclass Survived
# 1      0             80
#        1            136
# 2      0             97
#        1             87
# 3      0            372
#        1            119

# %%
# 데이터프레임에 색상 입히기 : style.background_gradient(cmap='summer_r')
train.groupby(['Pclass','Survived'])['Pclass'].count().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_bad2c_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_bad2c_row1_col0 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_bad2c_row2_col0 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_bad2c_row3_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_bad2c_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_bad2c_row5_col0 {
#   background-color: #ddee66;
#   color: #000000;
# }
# </style>
# <table id="T_bad2c_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Pclass</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bad2c_level0_row0" class="row_heading level0 row0" rowspan="2">1</th>
#       <th id="T_bad2c_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_bad2c_row0_col0" class="data row0 col0" >80</td>
#     </tr>
#     <tr>
#       <th id="T_bad2c_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_bad2c_row1_col0" class="data row1 col0" >136</td>
#     </tr>
#     <tr>
#       <th id="T_bad2c_level0_row2" class="row_heading level0 row2" rowspan="2">2</th>
#       <th id="T_bad2c_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_bad2c_row2_col0" class="data row2 col0" >97</td>
#     </tr>
#     <tr>
#       <th id="T_bad2c_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_bad2c_row3_col0" class="data row3 col0" >87</td>
#     </tr>
#     <tr>
#       <th id="T_bad2c_level0_row4" class="row_heading level0 row4" rowspan="2">3</th>
#       <th id="T_bad2c_level1_row4" class="row_heading level1 row4" >0</th>
#       <td id="T_bad2c_row4_col0" class="data row4 col0" >372</td>
#     </tr>
#     <tr>
#       <th id="T_bad2c_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_bad2c_row5_col0" class="data row5 col0" >119</td>
#     </tr>
#   </tbody>
# </table>

# %%
# No. 67 - Groupby - mean - cmap

# %%
# No. 68 - Groupby - Crosstab

# %%
# crosstab : 요인(factors)별로 교차분석(cross tabulations)해서, 
# 행, 열 요인 기준 별로 빈도를 세어서 도수분포표(frequency table), 교차표(contingency table) 를 만들어줌
# 출처 : https://rfriend.tistory.com/280

pd.crosstab(train.Survived, train.Pclass, margins=True) # margins = 총 합계
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %%
# No. 69 - where

# %%
data.Age.value_counts()
# Out:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %%
top5 = train.Age.value_counts().nlargest(5).index
top5
# Out:
# Float64Index([24.0, 22.0, 18.0, 19.0, 28.0], dtype='float64')

# %%
data['Agroup'] = 1
# 나이 기준 별 A그룹 컬럼에 값 넣기 
data.loc[(data.Age.values < 24.0), 'Agroup']= 0
data.loc[(data.Age.values > 30.0), 'Agroup']= 2

data.head(20)
# Out:
#      Age Cabin Embarked     Fare  \
# 0   22.0   NaN        S   7.2500
# 1   38.0   C85        C  71.2833
# 2   26.0   NaN        S   7.9250
# 3   35.0  C123        S  53.1000
# 4   35.0   NaN        S   8.0500
# 5    NaN   NaN        Q   8.4583
# 6   54.0   E46        S  51.8625
# 7    2.0   NaN        S  21.0750
# 8   27.0   NaN        S  11.1333
# 9   14.0   NaN        C  30.0708
# 10   4.0    G6        S  16.7000
# 11  58.0  C103        S  26.5500
# 12  20.0   NaN        S   8.0500
# 13  39.0   NaN        S  31.2750
# 14  14.0   NaN        S   7.8542
# 15  55.0   NaN        S  16.0000
# 16   2.0   NaN        Q  29.1250
# 17   NaN   NaN        S  13.0000
# 18  31.0   NaN        S  18.0000
# 19   NaN   NaN        C   7.2250
#
#                                                  Name  Parch  ...  Pclass  \
# 0                             Braund, Mr. Owen Harris      0  ...       3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0  ...       1
# 2                              Heikkinen, Miss. Laina      0  ...       3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  ...       1
# 4                            Allen, Mr. William Henry      0  ...       3
# 5                                    Moran, Mr. James      0  ...       3
# 6                             McCarthy, Mr. Timothy J      0  ...       1
# 7                      Palsson, Master. Gosta Leonard      1  ...       3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2  ...       3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)      0  ...       2
# 10                    Sandstrom, Miss. Marguerite Rut      1  ...       3
# 11                           Bonnell, Miss. Elizabeth      0  ...       1
# 12                     Saundercock, Mr. William Henry      0  ...       3
# 13                        Andersson, Mr. Anders Johan      5  ...       3
# 14               Vestrom, Miss. Hulda Amanda Adolfina      0  ...       3
# 15                   Hewlett, Mrs. (Mary D Kingcome)       0  ...       2
# 16                               Rice, Master. Eugene      1  ...       3
# 17                       Williams, Mr. Charles Eugene      0  ...       2
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...      0  ...       3
# 19                            Masselmani, Mrs. Fatima      0  ...       3
#
#        Sex SibSp  Survived            Ticket Agroup
# 0     male     1       0.0         A/5 21171      0
# 1   female     1       1.0          PC 17599      2
# 2   female     0       1.0  STON/O2. 3101282      1
# 3   female     1       1.0            113803      2
# 4     male     0       0.0            373450      2
# 5     male     0       0.0            330877      1
# 6     male     0       0.0             17463      2
# 7     male     3       0.0            349909      0
# 8   female     0       1.0            347742      1
# 9   female     1       1.0            237736      0
# 10  female     1       1.0           PP 9549      0
# 11  female     0       1.0            113783      2
# 12    male     0       0.0         A/5. 2151      0
# 13    male     1       0.0            347082      2
# 14  female     0       0.0            350406      0
# 15  female     0       1.0            248706      2
# 16    male     4       0.0            382652      0
# 17    male     0       1.0            244373      1
# 18  female     1       0.0            345763      2
# 19  female     0       1.0              2649      1
#
# [20 rows x 13 columns]

# %%
# No. 70 - Grouping with bins

# %%
# # column 출력제한 해제
# pd.set_option('display.max_columns', 100)

# cut : 특정 조건에 맞게 데이터 분류
data['Age_Cuts'] = pd.cut(data.Age, 
                          bins=[0, 1, 3, 10, 18, 65, 99], 
                          labels=['Baby', 'Todler', 'Kid', 'Teens',  'Adult', 'Elderly'])
data.head(30)
# Out:
#      Age        Cabin Embarked      Fare  \
# 0   22.0          NaN        S    7.2500
# 1   38.0          C85        C   71.2833
# 2   26.0          NaN        S    7.9250
# 3   35.0         C123        S   53.1000
# 4   35.0          NaN        S    8.0500
# 5    NaN          NaN        Q    8.4583
# 6   54.0          E46        S   51.8625
# 7    2.0          NaN        S   21.0750
# 8   27.0          NaN        S   11.1333
# 9   14.0          NaN        C   30.0708
# 10   4.0           G6        S   16.7000
# 11  58.0         C103        S   26.5500
# 12  20.0          NaN        S    8.0500
# 13  39.0          NaN        S   31.2750
# 14  14.0          NaN        S    7.8542
# 15  55.0          NaN        S   16.0000
# 16   2.0          NaN        Q   29.1250
# 17   NaN          NaN        S   13.0000
# 18  31.0          NaN        S   18.0000
# 19   NaN          NaN        C    7.2250
# 20  35.0          NaN        S   26.0000
# 21  34.0          D56        S   13.0000
# 22  15.0          NaN        Q    8.0292
# 23  28.0           A6        S   35.5000
# 24   8.0          NaN        S   21.0750
# 25  38.0          NaN        S   31.3875
# 26   NaN          NaN        C    7.2250
# 27  19.0  C23 C25 C27        S  263.0000
# 28   NaN          NaN        Q    7.8792
# 29   NaN          NaN        S    7.8958
#
#                                                  Name  Parch  ...     Sex  \
# 0                             Braund, Mr. Owen Harris      0  ...    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0  ...  female
# 2                              Heikkinen, Miss. Laina      0  ...  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  ...  female
# 4                            Allen, Mr. William Henry      0  ...    male
# 5                                    Moran, Mr. James      0  ...    male
# 6                             McCarthy, Mr. Timothy J      0  ...    male
# 7                      Palsson, Master. Gosta Leonard      1  ...    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2  ...  female
# 9                 Nasser, Mrs. Nicholas (Adele Achem)      0  ...  female
# 10                    Sandstrom, Miss. Marguerite Rut      1  ...  female
# 11                           Bonnell, Miss. Elizabeth      0  ...  female
# 12                     Saundercock, Mr. William Henry      0  ...    male
# 13                        Andersson, Mr. Anders Johan      5  ...    male
# 14               Vestrom, Miss. Hulda Amanda Adolfina      0  ...  female
# 15                   Hewlett, Mrs. (Mary D Kingcome)       0  ...  female
# 16                               Rice, Master. Eugene      1  ...    male
# 17                       Williams, Mr. Charles Eugene      0  ...    male
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...      0  ...  female
# 19                            Masselmani, Mrs. Fatima      0  ...  female
# 20                               Fynney, Mr. Joseph J      0  ...    male
# 21                              Beesley, Mr. Lawrence      0  ...    male
# 22                        McGowan, Miss. Anna "Annie"      0  ...  female
# 23                       Sloper, Mr. William Thompson      0  ...    male
# 24                      Palsson, Miss. Torborg Danira      1  ...  female
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5  ...  female
# 26                            Emir, Mr. Farred Chehab      0  ...    male
# 27                     Fortune, Mr. Charles Alexander      2  ...    male
# 28                      O'Dwyer, Miss. Ellen "Nellie"      0  ...  female
# 29                                Todoroff, Mr. Lalio      0  ...    male
#
#     SibSp Survived            Ticket  Agroup Age_Cuts
# 0       1      0.0         A/5 21171       0    Adult
# 1       1      1.0          PC 17599       2    Adult
# 2       0      1.0  STON/O2. 3101282       1    Adult
# 3       1      1.0            113803       2    Adult
# 4       0      0.0            373450       2    Adult
# 5       0      0.0            330877       1      NaN
# 6       0      0.0             17463       2    Adult
# 7       3      0.0            349909       0   Todler
# 8       0      1.0            347742       1    Adult
# 9       1      1.0            237736       0    Teens
# 10      1      1.0           PP 9549       0      Kid
# 11      0      1.0            113783       2    Adult
# 12      0      0.0         A/5. 2151       0    Adult
# 13      1      0.0            347082       2    Adult
# 14      0      0.0            350406       0    Teens
# 15      0      1.0            248706       2    Adult
# 16      4      0.0            382652       0   Todler
# 17      0      1.0            244373       1      NaN
# 18      1      0.0            345763       2    Adult
# 19      0      1.0              2649       1      NaN
# 20      0      0.0            239865       2    Adult
# 21      0      1.0            248698       2    Adult
# 22      0      1.0            330923       0    Teens
# 23      0      1.0            113788       1    Adult
# 24      3      0.0            349909       0      Kid
# 25      1      1.0            347077       2    Adult
# 26      0      0.0              2631       1      NaN
# 27      3      0.0             19950       0    Adult
# 28      0      1.0            330959       1      NaN
# 29      0      0.0            349216       1      NaN
#
# [30 rows x 14 columns]

# %% [markdown]
# # Part 7 - Appending/Inserting

# %%
data.insert(3, 'New1', 0)

data.head()
# Out:
#     Age Cabin Embarked  New1     Fare  \
# 0  22.0   NaN        S     0   7.2500
# 1  38.0   C85        C     0  71.2833
# 2  26.0   NaN        S     0   7.9250
# 3  35.0  C123        S     0  53.1000
# 4  35.0   NaN        S     0   8.0500
#
#                                                 Name  ...     Sex  SibSp  \
# 0                            Braund, Mr. Owen Harris  ...    male      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  ...  female      1
# 2                             Heikkinen, Miss. Laina  ...  female      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  ...  female      1
# 4                           Allen, Mr. William Henry  ...    male      0
#
#    Survived            Ticket  Agroup  Age_Cuts
# 0       0.0         A/5 21171       0     Adult
# 1       1.0          PC 17599       2     Adult
# 2       1.0  STON/O2. 3101282       1     Adult
# 3       1.0            113803       2     Adult
# 4       0.0            373450       2     Adult
#
# [5 rows x 15 columns]

# %% [markdown]
# # Part 8 - Replacing

# %% [markdown]
# # Part 9 Others

# %%
# No. 82 - Drop columns by label names

# %%
data.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'New1', 'Fare', 'Name', 'Parch',
#        'PassengerId', 'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Agroup',
#        'Age_Cuts'],
#       dtype='object')

# %%
data = data.drop('New1', axis=1)

data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  ...     Sex  \
# 0                            Braund, Mr. Owen Harris      0  ...    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0  ...  female
# 2                             Heikkinen, Miss. Laina      0  ...  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  ...  female
# 4                           Allen, Mr. William Henry      0  ...    male
#
#    SibSp Survived            Ticket  Agroup Age_Cuts
# 0      1      0.0         A/5 21171       0    Adult
# 1      1      1.0          PC 17599       2    Adult
# 2      0      1.0  STON/O2. 3101282       1    Adult
# 3      1      1.0            113803       2    Adult
# 4      0      0.0            373450       2    Adult
#
# [5 rows x 14 columns]

# %%
# No. 83 - get group

# %%
# 원하는 그룹만 추출하기
a = data.groupby('Pclass').get_group(1)
a
# Out:
#       Age Cabin Embarked      Fare  \
# 1    38.0   C85        C   71.2833
# 3    35.0  C123        S   53.1000
# 6    54.0   E46        S   51.8625
# 11   58.0  C103        S   26.5500
# 23   28.0    A6        S   35.5000
# ..    ...   ...      ...       ...
# 403  17.0   NaN        S   47.1000
# 404  43.0   D40        C   27.7208
# 407  50.0   C80        C  211.5000
# 411  37.0   C78        Q   90.0000
# 414  39.0  C105        C  108.9000
#
#                                                   Name  Parch  ...     Sex  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0  ...  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  ...  female
# 6                              McCarthy, Mr. Timothy J      0  ...    male
# 11                            Bonnell, Miss. Elizabeth      0  ...  female
# 23                        Sloper, Mr. William Thompson      0  ...    male
# ..                                                 ...    ...  ...     ...
# 403                             Carrau, Mr. Jose Pedro      0  ...    male
# 404                       Frauenthal, Mr. Isaac Gerald      0  ...    male
# 407                         Widener, Mr. George Dunton      1  ...    male
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)      0  ...  female
# 414                       Oliva y Ocana, Dona. Fermina      0  ...  female
#
#      SibSp Survived    Ticket  Agroup Age_Cuts
# 1        1      1.0  PC 17599       2    Adult
# 3        1      1.0    113803       2    Adult
# 6        0      0.0     17463       2    Adult
# 11       0      1.0    113783       2    Adult
# 23       0      1.0    113788       1    Adult
# ..     ...      ...       ...     ...      ...
# 403      0      NaN    113059       0    Teens
# 404      1      NaN     17765       2    Adult
# 407      1      NaN    113503       2    Adult
# 411      1      NaN     19928       2    Adult
# 414      0      NaN  PC 17758       2    Adult
#
# [323 rows x 14 columns]

# %%
# No. 84 - Using missingno from matplotlib to see missing values

# %%
# 시각화 관련 라이브러리

# %matplotlib inline                
# 쥬피터 노트북 라인에 바로 그래프 그릴 수 있게
import matplotlib.pyplot as plt    # 시각화
plt.style.use('seaborn-whitegrid')   # 스타일 적용
import seaborn as sns     # 시각화
data.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# Agroup            0
# Age_Cuts        263
# dtype: int64

# %%
import missingno

missingno.matrix(data, figsize = (15,8))
# Out:
# <AxesSubplot:>

# %%
# (참고) No. 85 - Co-relation matrix

# %%
corr = data.corr()

# 마스크 셋업
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# plt 그래프 그리기
plt.figure(figsize=(14, 8))    # 그래프 셋업
plt.title('Overall Correlation of Titanic Features', fontsize=18)   # 그래프 타이틀
sns.heatmap(corr, mask=mask, annot=False,cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()
# Out:
# C:\Users\한국인\AppData\Local\Temp/ipykernel_6532/2308347549.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
# (참고) No. 86 - Dispalying pie chart and countplot together using matplotlib

# %%
f,ax=plt.subplots(1,2,figsize=(15,6))
train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=train,ax=ax[1])
ax[1].set_title('Survived')
plt.show()
# Out:
# C:\anacon\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
