# %%
import pandas as pd
import numpy as np 
DataUrl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv'
df = pd.read_csv(DataUrl,sep='\t')


#3번 행 열 갯수 출력 
# Ans = df.head(5)
# print(df.shape)
# print('행: ',df.shape[0])
# print('열: ',df.shape[1])

#4번 컬럼 출력 
# Ans = df.columns
# print(Ans)
#5번 6번째 컬럼 출력
# Ans[5]
#7번 데이터셋 인덱스 구성은 어떠한가. 
Ans = df.index
print(Ans)
#8번  6번째 컬럼의 3번째 값
Ans = df.iloc[2,5]
print(Ans)
# Out:
# RangeIndex(start=0, stop=51490, step=1)
# 2

# %%
DataUrl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/Jeju.csv'
df = pd.read_csv(DataUrl,encoding='euc-kr')

# %%
#10번 마지막 3개의 행을 출력시오.,
Ans = df.tail(3)
print(Ans)
#11번 수치형 변수를 가진 컬럼 출력  반대는 exclude -> include 
Ans = df.select_dtypes(exclude=object).columns
Ans
# Out:
#          id          일자   시도명 읍면동명         거주인구       근무인구        방문인구  \
# 9618  32066  2020-04-30   제주시  도두동    28397.481   3144.895   84052.697
# 9619  32067  2020-04-30  서귀포시  안덕면   348037.846  29106.286  251129.660
# 9620  32068  2020-04-30   제주시   연동  1010643.372  65673.477  447622.068
#
#            총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속
# 9618   115595.073  41.053    29.421   20.3   0.0    3.0
# 9619   628273.792  46.595    49.189   17.6   0.0    3.5
# 9620  1523938.917  40.863    27.765   14.1   0.0    4.8
# Index(['id', '거주인구', '근무인구', '방문인구', '총 유동인구', '평균 속도', '평균 소요 시간', '평균 기온',
#        '일강수량', '평균 풍속'],
#       dtype='object')

# %%
#13 각 컬럼 결측치 숫자 파악 
Ans = df.isnull().sum()
Ans
#14 각 컬럼 데이터수 타입 한번에 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9621 entries, 0 to 9620
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        9621 non-null   int64
#  1   일자        9621 non-null   object
#  2   시도명       9621 non-null   object
#  3   읍면동명      9621 non-null   object
#  4   거주인구      9621 non-null   float64
#  5   근무인구      9621 non-null   float64
#  6   방문인구      9621 non-null   float64
#  7   총 유동인구    9621 non-null   float64
#  8   평균 속도     9621 non-null   float64
#  9   평균 소요 시간  9621 non-null   float64
#  10  평균 기온     9621 non-null   float64
#  11  일강수량      9621 non-null   float64
#  12  평균 풍속     9621 non-null   float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 977.3+ KB

# %%
#15 각 수치형 변수의 분포( 사분위 평균 표준편차 최대 최소 ) 확인
Ans = df.describe()
Ans
# Out:
#                  id          거주인구           근무인구           방문인구        총 유동인구  \
# count   9621.000000  9.621000e+03    9621.000000    9621.000000  9.621000e+03
# mean   27258.000000  3.174315e+05   35471.201510  195889.561802  5.487922e+05
# std     2777.487804  2.982079e+05   40381.214775  140706.090325  4.608802e+05
# min    22448.000000  9.305552e+03    1407.936000   11538.322000  2.225181e+04
# 25%    24853.000000  9.539939e+04   12074.498000   99632.153000  2.216910e+05
# 50%    27258.000000  2.221105e+05   21960.928000  152805.335000  3.866935e+05
# 75%    29663.000000  4.106671e+05   40192.032000  236325.109000  6.406918e+05
# max    32068.000000  1.364504e+06  263476.965000  723459.209000  2.066484e+06
#
#              평균 속도     평균 소요 시간        평균 기온         일강수량        평균 풍속
# count  9621.000000  9621.000000  9621.000000  9621.000000  9621.000000
# mean     41.109084    37.215873    13.550828     6.972426     2.753171
# ...

# %%
#16 거주 인구 컬럼 값 출력
Ans = df['거주인구'].index
print(Ans)
# Out:
# RangeIndex(start=0, stop=9621, step=1)

# %%
#평균 속도 컬럼의 4분위 범위(IQR) 값을 구하여라
Ans  = df['평균 속도'].quantile(0.75) -df['평균 속도'].quantile(0.25)
Ans
# Out:
# 14.854999999999997

# %%
# 19번 읍면동 컬럼 유일값 출력
Ans = df['읍면동명'].unique()
Ans
# Out:
# array(['도두동', '외도동', '이도2동', '일도1동', '대천동', '서홍동', '한경면', '송산동', '조천읍',
#        '일도2동', '영천동', '예래동', '대륜동', '삼도1동', '이호동', '건입동', '중앙동', '삼양동',
#        '삼도2동', '이도1동', '남원읍', '대정읍', '정방동', '효돈동', '아라동', '한림읍', '구좌읍',
#        '용담1동', '오라동', '화북동', '연동', '표선면', '중문동', '성산읍', '안덕면', '천지동',
#        '노형동', '동홍동', '용담2동', '봉개동', '애월읍'], dtype=object)

# %%
DataUrl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv'
df = pd.read_csv(DataUrl)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
Ans = df.loc[df['quantity']==3,:]
print(Ans)
# Out:
#       order_id  quantity                            item_name  \
# 409        178         3                         Chicken Bowl
# 445        193         3                                 Bowl
# 689        284         3                    Canned Soft Drink
# 818        338         3                        Bottled Water
# 850        350         3                    Canned Soft Drink
# 917        379         3                    Canned Soft Drink
# 1255       511         3                        Steak Burrito
# 1514       616         3                         Chicken Bowl
# 1559       633         3                    Canned Soft Drink
# 2645      1051         3                  Chips and Guacamole
# 2823      1121         3                        Bottled Water
# 2936      1167         3                                Chips
# 2944      1170         3                        Side of Chips
# 2972      1182         3  Chips and Tomatillo-Red Chili Salsa
# ...

# %%
# Quantity 컬럼에서 3의 값을가져 0부터 정렬하고 첫 5행
Ans = df.loc[ df['quantity'] == 3 ].head().reset_index(drop=True)
Ans
# Out:
#    order_id  quantity          item_name  \
# 0       178         3       Chicken Bowl
# 1       193         3               Bowl
# 2       284         3  Canned Soft Drink
# 3       338         3      Bottled Water
# 4       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %%
#23번 두개의 컬럼으로 구성된 데이터 프레임 정의 
Ans =df[['quantity','item_price']]
Ans
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %%
df['new_price'] = df['item_price'].str[1:].astype('float')
Ans = df['new_price'].head()
Ans
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: new_price, dtype: float64

# %%
# 25 new price 데이터값이 5 이하인 데이터 수 
Ans = df.loc[df['new_price'] <= 5]
len(Ans)
# Out:
# 1652

# %%
Ans = df.loc[ df['item_name'] == 'Chicken Salad Bowl'].reset_index(drop=True)
Ans.head(3)
# Out:
#    order_id  quantity           item_name  \
# 0        20         1  Chicken Salad Bowl
# 1        60         2  Chicken Salad Bowl
# 2        94         2  Chicken Salad Bowl
#
#                                   choice_description item_price  new_price
# 0  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 1  [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50       22.50
# 2  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50       22.50

# %%
Ans = df.loc[(df['new_price']<=9) & (df['item_name'] ==  'Chicken Salad Bowl')]
Ans
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 526        220         1  Chicken Salad Bowl
# 528        221         1  Chicken Salad Bowl
# 529        221         1  Chicken Salad Bowl
# 568        234         1  Chicken Salad Bowl
# 585        240         1  Chicken Salad Bowl
# 693        286         1  Chicken Salad Bowl
# 702        289         1  Chicken Salad Bowl
# 762        314         1  Chicken Salad Bowl
# 1109       458         1  Chicken Salad Bowl
# 1460       592         1  Chicken Salad Bowl
# 1471       598         1  Chicken Salad Bowl
# 1483       602         1  Chicken Salad Bowl
# 1547       628         1  Chicken Salad Bowl
# 1601       649         1  Chicken Salad Bowl
# 1621       654         1  Chicken Salad Bowl
# 1756       709         1  Chicken Salad Bowl
# 1977       798         1  Chicken Salad Bowl
# 2031       818         1  Chicken Salad Bowl
# ...

# %%
# 28번 
Ans = df.sort_values('new_price').reset_index(drop = True)
Ans.head(4)
# Out:
#    order_id  quantity      item_name choice_description item_price  new_price
# 0       471         1  Bottled Water                NaN     $1.09        1.09
# 1       338         1    Canned Soda        [Coca Cola]     $1.09        1.09
# 2      1575         1    Canned Soda       [Dr. Pepper]     $1.09        1.09
# 3        47         1    Canned Soda       [Dr. Pepper]     $1.09        1.09

# %%
#29번 item_name 컬럼 값중 Chips 포함하는 경우의 데이터를 출력하라
# str.contains('문자열') --> str안에 '문자열' 을 포함하는 
Ans = df.loc[df['item_name'].str.contains('Chips')]
Ans.head(5)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 6          3         1                          Side of Chips
# 10         5         1                    Chips and Guacamole
# 14         7         1                    Chips and Guacamole
#
#    choice_description item_price  new_price
# 0                 NaN     $2.39        2.39
# 3                 NaN     $2.39        2.39
# 6                 NaN     $1.69        1.69
# 10                NaN     $4.45        4.45
# 14                NaN     $4.45        4.45

# %%
#df의 짝수번째 컬럼만을 포함하는 데이터프레임을 출력하라
Ans = df.iloc[:,::2]
Ans
# Out:
#       order_id                              item_name item_price
# 0            1           Chips and Fresh Tomato Salsa     $2.39
# 1            1                                   Izze     $3.39
# 2            1                       Nantucket Nectar     $3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2                           Chicken Bowl    $16.98
# ...        ...                                    ...        ...
# 4617      1833                          Steak Burrito    $11.75
# 4618      1833                          Steak Burrito    $11.75
# 4619      1834                     Chicken Salad Bowl    $11.25
# 4620      1834                     Chicken Salad Bowl     $8.75
# 4621      1834                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 3 columns]

# %%
Ans = df.sort_values('new_price',ascending = False).reset_index(drop = True)
Ans
# Out:
#       order_id  quantity                     item_name  \
# 0         1443        15  Chips and Fresh Tomato Salsa
# 1         1398         3                 Carnitas Bowl
# 2          511         4               Chicken Burrito
# 3         1443         4               Chicken Burrito
# 4         1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 4617      1578         1                   Canned Soda
# 4618      1162         1                 Bottled Water
# 4619       567         1                   Canned Soda
# 4620      1014         1                   Canned Soda
# 4621       591         1                   Canned Soda
#
#                                      choice_description item_price  new_price
# 0                                                   NaN    $44.25       44.25
# 1     [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25       35.25
# ...

# %%
#34 중복 제거 
Ans = df.loc[(df['item_name']=='Steak Salad') | (df['item_name'] == 'Bowl')]
Ans = Ans.drop_duplicates('item_name')
Ans
# Out:
#      order_id  quantity    item_name  \
# 445       193         3         Bowl
# 664       276         1  Steak Salad
#
#                                     choice_description item_price  new_price
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20       22.20
# 664  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99        8.99

# %%
#35 df new_price값이 new_price값의 평균값 이상을 가지는 데이터들을 인덱싱하라
Ans = df.loc[df.new_price>=df.new_price.mean()]
Ans.head(5)
# Out:
#    order_id  quantity         item_name  \
# 4         2         2      Chicken Bowl
# 5         3         1      Chicken Bowl
# 7         4         1     Steak Burrito
# 8         4         1  Steak Soft Tacos
# 9         5         1     Steak Burrito
#
#                                   choice_description item_price  new_price
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98       10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25        9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25

# %%
#36  df의 데이터 중 item_name의 값이 Izze 데이터를 Fizzy Lizzy로 수정하라
# 'item_name' 지정을 해주지 않으면 다른 Izze 의 값들도 같이 변하기 때문 
df.loc[df.item_name =='Izze','item_name'] = 'Fizzy Lizzy'
Ans = df
#40 df의 데이터 중 choice_description 값에 
#    Vegetables 들어가지 않는 경우의 갯수를 출력하라
Ans = len(df.loc[~df.choice_description.str.contains('Vegetables')])
# ~ 있는  경우 True -> False , False -> True
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17276/2916398402.py in <module>
#       5 #40 df의 데이터 중 choice_description 값에
#       6 #    Vegetables 들어가지 않는 경우의 갯수를 출력하라
# ----> 7 Ans = len(df.loc[~df.choice_description.str.contains('Vegetables')])
#       8 # ~ 있는  경우 True -> False , False -> True
#
# C:\anacon\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1530             return self
#    1531
# -> 1532         new_data = self._mgr.apply(operator.invert)
#    1533         return self._constructor(new_data).__finalize__(self, method="__invert__")
#    1534
#
# C:\anacon\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     323             try:
#     324                 if callable(f):
# --> 325                     applied = b.apply(f, **kwargs)
# ...

# %%
# df 데이터중 item_name 안거 갯수가 15개 이상 
Ans = df.loc[df['item_name'].str.len() >=15 ]
Ans

# %%
# df의 데이터 중 new_price값이 lst에 해당하는 경우의 데이터 프레임을 구하고
# 그 갯수를 출력하라 
# isin(?)   ?에 해당하는 데이터 값 
lst =[1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98]

Ans = df.loc[df.new_price.isin(lst)]
display(Ans.head(3))
print(len(Ans))

# %%
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv')
Ans =df.head(5)
Ans

# %%
# 46 데이터의 각 host_name의 빈도수를 구하고 빈도수 
# 기준 내림차순 정렬한 데이터 프레임을 만들어라. 
# 빈도수 컬럼은 counts로 명명하라
Ans = df.groupby('host_name').size().\
               to_frame().rename(columns={0:'counts'}).\
               sort_values('counts',ascending=False)
Ans.head(5)
# to_frame().rename(columns={0:'counts'}).\
#   sort_values('counts',ascending=False)
# 새 데이터 프레임 컬럼은 counts로 명명, 내림차순 정렬
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17276/3259213421.py in <module>
#       2 # 기준 내림차순 정렬한 데이터 프레임을 만들어라.
#       3 # 빈도수 컬럼은 counts로 명명하라
# ----> 4 Ans = df.groupby('host_name').size().\
#       5                to_frame().rename(columns={0:'counts'}).\
#       6                sort_values('counts',ascending=False)
#
# C:\anacon\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ...

# %%
#48 neighbourhood_group의 값에 따른 neighbourhood컬럼 값의 갯수를 구하여라

# %%
lst =[1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98]

Ans = df.loc[df.new_price.isin(lst)]

display(Ans.head(5))

# %%
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv')



Ans= df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()\
                  .groupby(['neighbourhood_group'], as_index=False).max()

Ans1 =  df.groupby(['neighbourhood_group','neighbourhood'], as_index=True).size()\
                  .groupby(['neighbourhood_group'], as_index=True).max()
print(Ans)

print(Ans1)

# %%
df[df.item_name.str.len() >=15]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4615      1832         1                     Chicken Soft Tacos
# 4616      1832         1                    Chips and Guacamole
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $2.39        2.39
# ...

# %%
Ans = df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17276/474887711.py in <module>
# ----> 1 Ans = df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()
#
# C:\anacon\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# C:\anacon\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...

# %%
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv')

Ans
# Out:
#     neighbourhood_group  neighbourhood  size
# 0                 Bronx       Allerton    42
# 1                 Bronx     Baychester     7
# 2                 Bronx        Belmont    24
# 3                 Bronx      Bronxdale    19
# 4                 Bronx    Castle Hill     9
# ..                  ...            ...   ...
# 216       Staten Island    Tottenville     7
# 217       Staten Island  West Brighton    18
# 218       Staten Island    Westerleigh     2
# 219       Staten Island    Willowbrook     1
# 220       Staten Island        Woodrow     1
#
# [221 rows x 3 columns]

# %%
Ans = df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()
Ans2 = df.groupby(['neighbourhood_group','neighbourhood'], as_index=True).size()
print('False\n',Ans)

print('True\n',Ans2)
# Out:
# False
#      neighbourhood_group  neighbourhood  size
# 0                 Bronx       Allerton    42
# 1                 Bronx     Baychester     7
# 2                 Bronx        Belmont    24
# 3                 Bronx      Bronxdale    19
# 4                 Bronx    Castle Hill     9
# ..                  ...            ...   ...
# 216       Staten Island    Tottenville     7
# 217       Staten Island  West Brighton    18
# 218       Staten Island    Westerleigh     2
# 219       Staten Island    Willowbrook     1
# 220       Staten Island        Woodrow     1
#
# [221 rows x 3 columns]
# True
#  neighbourhood_group  neighbourhood
# Bronx                Allerton         42
#                      Baychester        7
#                      Belmont          24
#                      Bronxdale        19
#                      Castle Hill       9
#                                       ..
# Staten Island        Tottenville       7
#                      West Brighton    18
# ...

# %%
Ans = df[['neighbourhood_group','room_type']].groupby(['neighbourhood_group','room_type']).size().unstack()
Ans.loc[:,:] = (Ans.values /Ans.sum(axis=1).values.reshape(-1,1))
Ans.values
# Out:
# array([[0.34738772, 0.59761687, 0.05499542],
#        [0.47547752, 0.50397931, 0.02054318],
#        [0.60934398, 0.36849638, 0.02215964],
#        [0.36992587, 0.59512884, 0.03494529],
#        [0.47184987, 0.50402145, 0.02412869]])

# %%
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/BankChurnersUp.csv',index_col=0)
Ans =df.shape
df['Customer_Age']
# Out:
# 0        45
# 1        49
# 2        51
# 3        40
# 4        40
#          ..
# 10122    50
# 10123    41
# 10124    44
# 10125    30
# 10126    43
# Name: Customer_Age, Length: 10127, dtype: int64

# %%
df['AgeState']  = df.Customer_Age.map(lambda x: x//10 *10)

Ans = df['AgeState'].sort_index()
Ans
# Out:
# 0        40
# 1        40
# 2        50
# 3        40
# 4        40
#          ..
# 10122    50
# 10123    40
# 10124    40
# 10125    30
# 10126    40
# Name: AgeState, Length: 10127, dtype: int64
